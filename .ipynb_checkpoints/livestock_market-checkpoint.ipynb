# %% [markdown]
# # Livestock Market Analysis

# %% [markdown]
# Analysis of the Livestock Market in the Caribean Region of Colombia.

# %% [markdown]
# ### OCR With Tesseract

# %% [markdown]
# OCR part done with Tesseract to recognize the characters in the pdf's.

# %%
# Import modules for OCR
try:
    import Image
except ImportError:
    from PIL import Image
import pytesseract

# Import os for getting image filenames in img directory
from os import listdir

# %%
# The cutoff represents the file where a new format starts
cutoff = "14-01-07.jpg"

# %%
# Image filenames 
image_filenames = [f for f in listdir("img") if ".jpg" in f]

# %%
# Auction filenames list
auction_filenames = []

# Temp ary of auction filename
temp_ary = []

# Generate auction filenames list
for index, filename in enumerate(image_filenames):
    # Append filename to temp_ary
    temp_ary.append(filename)
    # If it is the end append temp_ary no matter what
    if index == len(image_filenames)-1:
        auction_filenames.append(temp_ary)
    else:
        # Select next filename root to check if it belongs to the same multipage file
        next_root_filename = "-".join(image_filenames[index+1].replace(".jpg", "").split("-")[0:3])
        # If the next filename is another page of the same file go on and keep appending to temp_ary
        if next_root_filename in filename:
            pass
        # Else apppend temp ary and empty it
        else:
            auction_filenames.append(temp_ary)
            temp_ary = []

# %%
# Check if it coincides with the number of pdf's records gotten from the auction webstie
if len(auction_filenames) == 458:
    print("Ente gut, alles gut!")
# Out:
# Ente gut, alles gut!

# %%
# Count to limit number of files for testing
count = -1

# Loop through each auction and process the image data into the dataframe
for auction_ary in auction_filenames:
    # Break on the count file iteration
    count += 1
    if count == 3:
        break
    # Category of livestock: Number of iron brands: 1st male, 2nd male, 1st female, 2nd female.
    current_category = ""
    # Auction filename
    for auction_filename in auction_ary:
        current_category = append_image_to_dataframe(auction_filename, current_category)
# Out:
# img/13-01-08.jpg
# Miércoles, 09 de Enero de 2013
#
# Teléfonos: (4) 8940027 - 8940060 -- Fax: 7959544 7909973
#
# SUBASTAR S.A
#
# Nit. 812.000.577—3
#
# Kilometro 8 via PIanetaRica
#
# Email: info@subastar.com.co
#
# SUBASTAR S.A.
# RESULTADOS GENERALES FERIA 00001 CIUDAD 001 TIPO GANADO GORDO DE 2013- No Incluye Facturas por Donacién
#
# MONTERIA
#
# 1/
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# EDAD CANT. PESO MINIMO MAXIMO PROMEDIO VALOR
# ANIM. MED. ANIMAL
# SUBASTA HEMBRA DE 1a
# 2 3/4 HV 5 370 2,580 2,580 2,580 954,600
# XX VE 76 472 2,380 2,740 2,557 1,210,308
# XX BH 1 404 1 ,000 1 ,000 1 ,000 404,000
# TOTALES 82
# SUBASTA MACHO DE 1a
# XX TO 8 647 2,680 2,860 2,765 1,785,980
# TOTALES 8
# SUBASTA HEMBRA DE 2a
# 2 HV 1 268 1 ,800 1 ,800 1 ,800 482,400
# 2 1/4 HV 1 298 2,200 2,200 2,200 655,600
# 2 1/2 HV 10 345 2,340 2,400 2,373 816,368
# 2 3/4 HV 1 364 2,600 2,600 2,600 946,400
# XX VE 163 391 1,950 2,560 2,279 903,677
# TOTALES 176
# SUBASTA MACHO DE 2a
# 2 1/2 MC 1 342 2,550 2,550 2,550 872,100
# 2 3/4 MC 1 396 2,640 2,640 2,640 1,045,440
# XX TO 3 507 2,740 2,780 2,760 1,399,293
# TOTALES 5
# TOTAL ANIMALES SUBASTADOS Y REMATADOS 271
#
# Sistema Subagan 7.0p / 2008 - @ Lina Medina Software Design y Cia Ltda
#
# 1
# ################################################
# img/13-01-10-0.jpg
# Viernes, 11 de Enero de 2013
#
# Teléfonos: (4) 8940027 - 8940060 -- Fax: 7959544 7909973
#
# SUBASTAR S.A
#
# Nit. 812.000.577—3
#
# Kilometro 8 via PIanetaRica
#
# Email: info@subastar.com.co
#
# SUBASTAR S.A.
#
# MONTERIA
#
# RESULTADOS GENERALES FERIA 00002 CIUDAD 001 TIPO GENERAL DE 2013- No Incluye Facturas por Donacién
#
# 1/
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# EDAD CANT. PESO MINIMO MAXIMO PROMEDIO VALOR
# ANIM. MED. ANIMAL
# SUBASTA HEMBRA DE 1a
# DEST. HL 18 127 2,100 2,100 2,100 266,467
# 1 1/4 HL 17 155 2,300 2,300 2,300 355,553
# 1 1/2 HL 25 208 2,100 2,250 2,175 444,492
# 1 3/4 HL 17 229 2,050 2,150 2,100 485,518
# 2 HV 18 278 2,350 2,350 2,350 654,083
# 2 HL 18 267 2,300 2,300 2,300 614,611
# 2 1/4 HV 12 283 2,350 2,350 2,350 665,050
# 2 1/4 HL 5 282 2,100 2,100 2,100 592,200
# TOTALES 130
# SUBASTA MACHO DE 1a
# 1 1/4 ML 45 165 2,700 2,850 2,783 459,371
# 1 1/2 ML 177 202 2,750 3,200 3,006 607,059
# 1 3/4 ML 72 241 2,800 3,000 2,888 700,174
# 2 MC 148 263 2,600 2,950 2,793 733,855
# 2 1/4 MC 84 296 2,660 2,900 2,766 825,719
# 2 1/2 MC 62 342 2,660 2,880 2,752 954,953
# 2 3/4 MC 47 381 2,700 2,800 2,747 1,049,547
# TOTALES 635
# SUBASTA HEMBRA DE 2a
# DEST. HL 5 121 2,250 2,350 2,300 277,460
# 1 1/4 HL 1 164 2,000 2,000 2,000 328,000
# 1 1/2 HL 3 202 1,700 1,900 1,800 371,267
# 2 HL 3 261 2,250 2,250 2,250 588,000
# XX VE 29 394 2,040 2,220 2,130 839,640
# TOTALES 41
# SUBASTA MACHO DE 2a
# DEST. ML 2 1 18 2,200 2,200 2,200 259,600
# 1 ML 11 146 2,450 2,800 2,617 375,500
# 1 1/4 ML 80 164 2,350 2,600 2,500 410,825
# 1 1/2 ML 148 200 1,900 2,700 2,390 499,548
# 1 3/4 ML 126 239 2,100 2,700 2,500 584,567
# 2 MC 35 276 2,400 2,600 2,500 699,943
# 2 1/4 MC 88 300 2,000 2,700 2,506 774,230
# 2 1/2 MC 2 332 2,360 2,360 2,360 783,520
# 2 3/4 MC 17 389 2,720 2,720 2,720 1,058,880
# TOTALES 509
#
#
#
# Sistema Subagan 7.0p / 2008 - @ Lina Medina Software Design y Cia Ltda
# ################################################
# img/13-01-10-1.jpg
# Viernes, 11 de Enero de 2013 2 / 2
#
# SUBASTAR S.A.
# RESULTADOS GENERALES FERIA 00002 CIUDAD 001 TIPO GENERAL DE 2013- No Incluye Facturas por Donacién
#
#
#
#
#
# EDAD CANT. PESO MINIMO MAXIMO PROMEDIO VALOR
# ANIM. MED. ANIMAL
# TOTAL ANIMALES SUBASTADOS Y REMATADOS 1,315
#
# Sistema Subagan 7.0p / 2008 - @ Lina Medina Software Design y Cia Ltda
# ################################################
# img/13-01-15.jpg
# Miércoles, 16 de Enero de 2013
#
# Teléfonos: (4) 8940027 - 8940060 -- Fax: 7959544 7909973
#
# SUBASTAR S.A
#
# Nit. 812.000.577—3
#
# Kilometro 8 via PIanetaRica
#
# Email: info@subastar.com.co
#
# SUBASTAR S.A.
# RESULTADOS GENERALES FERIA 00003 CIUDAD 001 TIPO GANADO GORDO DE 2013- No Incluye Facturas por Donacién
#
# MONTERIA
#
# 1/
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# EDAD CANT. PESO MINIMO MAXIMO PROMEDIO VALOR
# ANIM. MED. ANIMAL
# SUBASTA HEMBRA DE 1a
# 2 1/4 HV 2 313 2,200 2,200 2,200 688,600
# 2 1/2 HV 13 347 2,380 2,380 2,380 826,043
# 2 3/4 HV 5 380 2,380 2,380 2,380 903,448
# 3 HV 17 452 2,580 2,620 2,595 1,174,259
# XX VE 22 501 2,380 2,660 2,525 1,281,695
# TOTALES 59
# SUBASTA MACHO DE 1 a
# XX TO 9 580 2,400 2,980 2,660 1 ,544,969
# TOTALES 9
# SUBASTA HEMBRA DE 2a
# 2 1/4 HV 6 315 2,200 2,200 2,200 692,267
# 2 1/2 HV 16 339 2,360 2,360 2,360 800,630
# XX VE 69 413 1,100 2,460 2,107 906,671
# TOTALES 91
# SUBASTA MACHO DE 2a
# 2 3/4 MC 6 385 2,700 2,700 2,700 1,039,500
# XX TO 2 418 2,800 2,800 2,800 1,170,400
# TOTALES 8
# TOTAL ANIMALES SUBASTADOS Y REMATADOS 167
#
# Sistema Subagan 7.0p / 2008 - @ Lina Medina Software Design y Cia Ltda
#
# 1
# ################################################

# %%
# Method that pulls data from image and append it to dataframe. It returns the last iron brand category 
def append_image_to_dataframe(auction_filename, current_category):
    img_path = "img/{0}".format(auction_filename)
    print(img_path)
    img = Image.open(img_path)
    text = pytesseract.image_to_string(img)
    text.split("\n")
    print(text)
    print("################################################")
